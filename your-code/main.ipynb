# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Selenium Doc](https://www.selenium.dev/documentation/)
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `Selenium` and `pandas` are imported for you.

# %%
import pandas as pd
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# #### Enable the options you may need. In the next cell you have an example of them but you can choose to use them or not.

# %%
#driver configuration
opciones=Options()

opciones.add_experimental_option('excludeSwitches', ['enable-automation'])
opciones.add_experimental_option('useAutomationExtension', False)
opciones.headless=False    # si True, no aperece la ventana (headless=no visible)
opciones.add_argument('--start-maximized')         # comienza maximizado
#opciones.add_argument('user-data-dir=selenium')    # mantiene las cookies
#opciones.add_extension('driver_folder/adblock.crx')       # adblocker
opciones.add_argument('--incognito')

# %%
from selenium.webdriver.common.by import By # By es para buscar por tag, clase, id...

import time

import warnings
warnings.filterwarnings('ignore')

# %%
driver = "/Users/esteban/Phyton/4.3-lab_web_scraping_selenium/chromedriver_mac64/chromedriver" #remember substitute this for your driver path
driver = webdriver.Chrome(driver,options = opciones)

# %% [markdown]
# #### Download, parse, and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'
driver.get(url)

# %%
#your code
nombres = driver.find_elements(By.CLASS_NAME,'h3.lh-condensed')
nombres
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="680A8058D54A276C3C48379BEE6848B8_element_142")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="680A8058D54A276C3C48379BEE6848B8_element_163")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="680A8058D54A276C3C48379BEE6848B8_element_177")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="680A8058D54A276C3C48379BEE6848B8_element_178")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="680A8058D54A276C3C48379BEE6848B8_element_179")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="680A8058D54A276C3C48379BEE6848B8_element_180")>,
# ...

# %%
nombres = [e.text.strip() for e in driver.find_elements(By.CLASS_NAME,'h3.lh-condensed')]
nombres
# Out:
# ['Vectorized',
#  'Bas Nijholt',
#  'Matthew Leibowitz',
#  'Steven Tey',
#  'Michael Davis',
#  'Nikita Sobolev',
#  'xiaoyifang',
#  'Jeff Dickey',
#  'Henrik Rydgård',
#  'Jack Lloyd',
#  'Vadim Demedes',
#  'Jakub Beránek',
#  'Luke Latham',
#  'Ayush Chaurasia',
#  'Zhuohan Li',
#  'MichaIng',
#  'Dario Nieuwenhuis',
#  'boojack',
#  'Guilherme Branco Stracini',
#  'Corwin Smith',
#  'Yagiz Nizipli',
#  'Tom Payne',
#  'Adeeb Shihadeh',
#  'Jarrett Ye',
#  'Stanisław Pitucha']

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
#your code

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'
driver.get(url)

# %%
#your code
repos = driver.find_elements(By.CLASS_NAME,'h3.lh-condensed')
repos
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="BDD5E511BA761D4A768892E0C2BFC8BF_element_305")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="BDD5E511BA761D4A768892E0C2BFC8BF_element_311")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="BDD5E511BA761D4A768892E0C2BFC8BF_element_312")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="BDD5E511BA761D4A768892E0C2BFC8BF_element_313")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="BDD5E511BA761D4A768892E0C2BFC8BF_element_314")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="BDD5E511BA761D4A768892E0C2BFC8BF_element_315")>,
# ...

# %%
repos = [e.text.strip() for e in driver.find_elements(By.CLASS_NAME,'h3.lh-condensed')]
repos
# Out:
# ['bregman-arie / devops-exercises',
#  'TheAlgorithms / Python',
#  'Alpha-VLLM / LLaMA2-Accessory',
#  'ymcui / Chinese-LLaMA-Alpaca-2',
#  'commaai / openpilot',
#  'ultralytics / ultralytics',
#  'iam-veeramalla / aws-devops-zero-to-hero',
#  'geekan / MetaGPT',
#  'sweepai / sweep',
#  'jerryjliu / llama_index',
#  'wagtail / wagtail',
#  'bregman-arie / python-exercises',
#  'hegelai / prompttools',
#  'ShishirPatil / gorilla',
#  'sail-sg / EditAnything',
#  'bridgecrewio / checkov',
#  '521xueweihan / HelloGitHub',
#  'hiyouga / FastEdit',
#  'apple / ml-stable-diffusion',
#  'Mebus / cupp',
#  'xtekky / gpt4free',
#  'snap-stanford / med-flamingo',
#  'ultralytics / yolov5',
#  'donnemartin / system-design-primer',
#  'llm-attacks / llm-attacks']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'
driver.get(url)

# %%
#your codei

imagen= driver.find_elements(By.TAG_NAME,'img')
imagen
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="0396CF9185F0753DDD60B808A59052E3_element_44")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="0396CF9185F0753DDD60B808A59052E3_element_45")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="0396CF9185F0753DDD60B808A59052E3_element_47")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="0396CF9185F0753DDD60B808A59052E3_element_42")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="0396CF9185F0753DDD60B808A59052E3_element_43")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fcb291820ea12df495b3411fd36320cd", element="0396CF9185F0753DDD60B808A59052E3_element_41")>,
# ...

# %%
page= [i.get_attribute('src') for i in imagen]
page
# Out:
# ['https://en.wikipedia.org/static/images/icons/wikipedia.png',
#  'https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-wordmark-en.svg',
#  'https://en.wikipedia.org/static/images/mobile/copyright/wikipedia-tagline-en.svg',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png',
#  'https://upload.wikimedia.org/wikipedia/en/thumb/8/8c/Extended-protection-shackle.svg/20px-Extended-protection-shackle.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png',
#  'https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg/220px-Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg',
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python' 
driver.get(url)

# %%
#your code
py = driver.find_elements(By.CSS_SELECTOR,'li')
py
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="645071D4225D300D21BF522C423122DE_element_23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="645071D4225D300D21BF522C423122DE_element_24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="645071D4225D300D21BF522C423122DE_element_25")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="645071D4225D300D21BF522C423122DE_element_26")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="645071D4225D300D21BF522C423122DE_element_27")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="645071D4225D300D21BF522C423122DE_element_28")>,
# ...

# %%
elementos_a = driver.find_elements(By.TAG_NAME,'a')  

valores_href = [elemento.get_attribute('href') for elemento in elementos_a]  # Extrae los valores del atributo 'href'

valores_href
# Out:
# ['https://www.fbi.gov/wanted/topten#',
#  'https://www.fbi.gov/wanted/topten#',
#  'https://www.fbi.gov/@@search',
#  'https://www.fbi.gov/',
#  'https://www.fbi.gov/wanted',
#  'https://www.fbi.gov/news',
#  'https://www.fbi.gov/investigate',
#  'https://www.fbi.gov/how-we-can-help-you',
#  'https://www.fbi.gov/tips',
#  'https://www.fbi.gov/about',
#  'https://www.fbi.gov/contact-us',
#  'https://www.fbi.gov/',
#  'https://www.fbi.gov/wanted',
#  'https://www.facebook.com/FBI',
#  'https://delivery.fbi.gov/subscribe?utm_source=Email%20Icon%20-%20fbi.gov&utm_medium=Email%20Icon%20-%20fbi.gov&utm_campaign=Email%20Alerts%20Campaign&utm_term=email-alerts&utm_content=Email%20icon%20that%27s%20in%20the%20header%20toolbar%20on%20the%20fbi.gov%20website',
#  'https://twitter.com/FBI',
#  'https://www.youtube.com/user/fbi',
#  'https://www.fbi.gov/flickr',
#  'https://www.linkedin.com/company/fbi',
#  'https://www.instagram.com/fbi/',
#  'https://www.fbi.gov/',
# ...

# %%
# Out:
# []

# %% [markdown]
# #### Number of Titles that have changed in the United States Code since its last release point

# %%
# This is the url you will scrape in this exercise
url = 'http://uscode.house.gov/download/download.shtml'
driver.get(url)

# %%
#your code
title = driver.find_elements(By.CLASS_NAME,'usctitle')
len(title)
# Out:
# 54

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'
driver.get(url)

# %%
#your code 
fbi = driver.find_elements(By.CLASS_NAME,'title')
fbi
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="747FEB97436A76F95218A9D6E9E0D7F8_element_1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="747FEB97436A76F95218A9D6E9E0D7F8_element_2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="747FEB97436A76F95218A9D6E9E0D7F8_element_3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="747FEB97436A76F95218A9D6E9E0D7F8_element_4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="747FEB97436A76F95218A9D6E9E0D7F8_element_5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="747FEB97436A76F95218A9D6E9E0D7F8_element_6")>,
# ...

# %%
fbi = [e.text.strip() for e in driver.find_elements(By.CLASS_NAME,'title')]
fbi
# Out:
# ['MOST WANTED',
#  'ARNOLDO JIMENEZ',
#  'OMAR ALEXANDER CARDENAS',
#  'ALEXIS FLORES',
#  'YULAN ADONAY ARCHAGA CARIAS',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'WILVER VILLEGAS-PALOMINO',
#  'ALEJANDRO ROSALES CASTILLO',
#  'RUJA IGNATOVA',
#  'DONALD EUGENE FIELDS II',
#  'JOSE RODOLFO VILLARREAL-HERNANDEZ']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'
driver.get(url)

# %%
#your code
cookies = driver.find_element(By.XPATH,'//*[@id="cookieConsentContainer"]/a/div')
cookies.click()

# %%
data_a = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
        for f in driver.find_element(By.XPATH, '/html/body/div[3]/div[6]/table').find_elements(By.TAG_NAME, 'tr')]


data_a
# Out:
# [[],
#  ['',
#   '1',
#   '',
#   '2023-08-02 15:21:13\n7 min ago',
#   '19.035',
#   '-156.137',
#   '12',
#   '',
#   '3.6',
#   'HAWAII REGION, HAWAII'],
#  ['',
#   '',
#   '',
#   '2023-08-02 15:20:50\n8 min ago',
#   '12.600',
#   '-88.190',
#   '20',
#   '',
#   '2.5',
#   'OFFSHORE EL SALVADOR'],
#  ['',
#   '',
#   '',
#   '2023-08-02 15:05:34\n22 min ago',
#   '46.305',
#   '13.658',
#   '2',
#   '',
#   '0.8',
#   'SLOVENIA'],
#  ['',
#   '',
#   '',
#   '2023-08-02 14:48:35\n39 min ago',
#   '40.586',
#   '27.944',
#   '8',
#   '',
#   '2.7',
#   'WESTERN TURKEY'],
#  ['',
#   '',
#   '',
#   '2023-08-02 14:48:03\n40 min ago',
#   '37.644',
#   '35.852',
#   '7',
#   '',
#   '2.0',
#   'CENTRAL TURKEY'],
#  ['',
#   '',
#   '',
#   '2023-08-02 14:47:14\n41 min ago',
#   '-26.977',
#   '26.786',
#   '10',
#   '',
#   '3.3',
#   'SOUTH AFRICA'],
#  ['',
#   '',
#   '',
#   '2023-08-02 14:45:02\n43 min ago',
#   '-8.560',
#   '112.730',
#   '105',
#   '',
#   '3.1',
# ...

# %%
driver.find_elements(By.TAG_NAME,'tr')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="E90D1B8F3BBA64C939EA996D6D6D512E_element_646")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="E90D1B8F3BBA64C939EA996D6D6D512E_element_647")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="E90D1B8F3BBA64C939EA996D6D6D512E_element_648")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="E90D1B8F3BBA64C939EA996D6D6D512E_element_649")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="E90D1B8F3BBA64C939EA996D6D6D512E_element_650")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="80c271618f47bb88fe961453bf0c2286", element="E90D1B8F3BBA64C939EA996D6D6D512E_element_308")>,
# ...

# %%
data[0]
# Out:
# []

# %%
cabeceras_a = driver.find_element(By.TAG_NAME, 'thead').text.split('\n')

cabeceras_a
# Out:
# ['Citizen',
#  'response',
#  'Date & Time',
#  'UTC',
#  'Lat.',
#  'degrees',
#  'Lon.',
#  'degrees',
#  'Depth',
#  'km',
#  'Mag.[+] Region']

# %%
cabeceras_a = ['Citizen' 'response', 'UTC', 'Date','& Time','Lat.degrees', 'Lon.degrees','Depthkm', 'vacia', ""'Mag.[+]', 
'Region']

# %%
import pandas as pd

# %%
df = pd.DataFrame(data_a, columns=cabeceras_a)

df
# Out:
#     Citizenresponse   UTC  Date                                 & Time  \
# 0              None  None  None                                   None
# 1                       1               2023-08-02 15:21:13\n7 min ago
# 2                                       2023-08-02 15:20:50\n8 min ago
# 3                                      2023-08-02 15:05:34\n22 min ago
# 4                                      2023-08-02 14:48:35\n39 min ago
# ..              ...   ...   ...                                    ...
# 98                                2023-08-02 05:30:56\n9 hr 58 min ago
# 99                                2023-08-02 05:30:33\n9 hr 58 min ago
# 100                              2023-08-02 05:26:34\n10 hr 02 min ago
# 101                              2023-08-02 05:26:30\n10 hr 02 min ago
# 102                              2023-08-02 05:21:51\n10 hr 07 min ago
#
#     Lat.degrees Lon.degrees Depthkm vacia Mag.[+]  \
# 0          None        None    None  None    None
# ...

# %%
columnas_eliminar = ['Date','Citizenresponse','UTC','vacia']

# %%
df = df.drop(columnas_eliminar, axis=1)

# %%
df = df.drop(index=0)

# %%
df.head(10)
# Out:
#                              & Time Lat.degrees Lon.degrees Depthkm Mag.[+]  \
# 1    2023-08-02 15:21:13\n7 min ago      19.035    -156.137      12     3.6
# 2    2023-08-02 15:20:50\n8 min ago      12.600     -88.190      20     2.5
# 3   2023-08-02 15:05:34\n22 min ago      46.305      13.658       2     0.8
# 4   2023-08-02 14:48:35\n39 min ago      40.586      27.944       8     2.7
# 5   2023-08-02 14:48:03\n40 min ago      37.644      35.852       7     2.0
# 6   2023-08-02 14:47:14\n41 min ago     -26.977      26.786      10     3.3
# 7   2023-08-02 14:45:02\n43 min ago      -8.560     112.730     105     3.1
# 8   2023-08-02 14:33:46\n54 min ago      14.880     -94.090      32     4.0
# 9   2023-08-02 14:29:59\n58 min ago      46.246       6.962       3     1.5
# 10  2023-08-02 14:28:57\n59 min ago      38.115      38.451       5     2.8
#
#                           Region
# 1          HAWAII REGION, HAWAII
# 2           OFFSHORE EL SALVADOR
# ...

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'
driver.get(url)

# %%
lengua = [e.text.strip() for e in driver.find_elements(By.TAG_NAME,'strong')]
lengua [1:10]
# Out:
# ['Español',
#  'English',
#  '日本語',
#  'Русский',
#  'Deutsch',
#  'Français',
#  'Italiano',
#  '中文',
#  'Português']

# %%
datos= driver.find_elements(By.TAG_NAME,'bdi')
datos[0].text.strip()
# Out:
# '1 881 000+'

# %%
valores = [dato.text.strip() for dato in datos]
valores.reverse()

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'
driver.get(url)

# %%
#your code

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'
driver.get(url)

# %%
#your code
cabeceras = driver.find_element(By.TAG_NAME, 'thead').text.split()

cabeceras
# Out:
# ['Language',
#  'Native',
#  'speakers',
#  '(millions)',
#  'Language',
#  'family',
#  'Branch']

# %%
columna1=cabeceras[0]
columna2=cabeceras[1:4]
columna3=cabeceras[4:6]
columna4= cabeceras[6:7]

# %%
data = [[e.text for e in f.find_elements(By.TAG_NAME, 'td')] 
        for f in driver.find_element(By.TAG_NAME, 'tbody').find_elements(By.TAG_NAME, 'tr')]


data
# Out:
# [['Mandarin Chinese\n(incl. Standard Chinese, but excl. other varieties)',
#   '939',
#   'Sino-Tibetan',
#   'Sinitic'],
#  ['Spanish', '485', 'Indo-European', 'Romance'],
#  ['English', '380', 'Indo-European', 'Germanic'],
#  ['Hindi\n(excl. Urdu, and other languages)',
#   '345',
#   'Indo-European',
#   'Indo-Aryan'],
#  ['Portuguese', '236', 'Indo-European', 'Romance'],
#  ['Bengali', '234', 'Indo-European', 'Indo-Aryan'],
#  ['Russian', '147', 'Indo-European', 'Balto-Slavic'],
#  ['Japanese', '123', 'Japonic', 'Japanese'],
#  ['Yue Chinese\n(incl. Cantonese)', '86.1', 'Sino-Tibetan', 'Sinitic'],
#  ['Vietnamese', '85.0', 'Austroasiatic', 'Vietic'],
#  ['Turkish', '84.0', 'Turkic', 'Oghuz'],
#  ['Wu Chinese\n(incl. Shanghainese)', '83.4', 'Sino-Tibetan', 'Sinitic'],
#  ['Marathi', '83.2', 'Indo-European', 'Indo-Aryan'],
#  ['Telugu', '83.0', 'Dravidian', 'South-Central'],
#  ['Korean', '81.7', 'Koreanic', '—'],
#  ['French', '80.8', 'Indo-European', 'Romance'],
# ...

# %%
import pandas as pd
df = pd.DataFrame(data, columns=cabecera)

df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File /Volumes/Esteban/APLICACIONES/anaconda3/lib/python3.10/site-packages/pandas/core/internals/construction.py:969, in _finalize_columns_and_data(content, columns, dtype)
#     968 try:
# --> 969     columns = _validate_or_indexify_columns(contents, columns)
#     970 except AssertionError as err:
#     971     # GH#26429 do not raise user-facing AssertionError
#
# File /Volumes/Esteban/APLICACIONES/anaconda3/lib/python3.10/site-packages/pandas/core/internals/construction.py:1017, in _validate_or_indexify_columns(content, columns)
#    1015 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1016     # caller's responsibility to check for this...
# -> 1017     raise AssertionError(
#    1018         f"{len(columns)} columns passed, passed data had "
#    1019         f"{len(content)} columns"
# ...

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
